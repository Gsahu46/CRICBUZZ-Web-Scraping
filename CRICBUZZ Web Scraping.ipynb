# %%
import sys

# %%
import time

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
try:
    page=requests.get('http://www.cricbuzz.com/')
    
except Exception as e:
    error_type, error_obj, error_info = sys.exc_info()
    print ('ERROR FOR LINK: ',url)
    print (error_type, 'Line:', error_info.tb_linemo)
    
time.sleep(2)
soup = BeautifulSoup(page.text,'html.parser')
links = soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent .hide{display: none; visibility: hidden;}	[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak { display: none !important;}	.cb-hm-lft{margin-bottom:5px;padding:0 15px;}	.cb-hm-lft-hdr{margin:0; padding:15px 15px 0; color: #009270;} .cb-hm-mid {border-left: 5px solid #e3e6e3 ;border-right: 5px solid #e3e6e3 ;padding: 0 15px;} .cb-mtc ...
# .cb-user-itm{position:absolute; top:0; right:5px}</style> </div> </div> <div class="cb-user-itm cb-subnav"> <a href="/premium-subscription/user/login"><span class="cb-plus-ico cb-user-icon"></span></a> <nav class="cb-sub-navigation" id="cb-plus-dropdown" style="right:0px;"> <a class="cb-subnav-item" href="/premium-subscription/user/account-info" target="_self" title="My Account">My Account</a> <a class="cb-subnav-item" ng-click="sign_out_user(false)" target="_self" title="Sign Out">Sign Out</a></nav> </div><style>.cb-text-link{color:#1866db;}
# .cb-header-plus{margin-left: 20px;background: #000;}
# .cb-header-plus:hover, .cb-header-plus:active, .cb-header-plus:focus{background: #000;}</style><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/35178/ned-vs-ire-3rd-odi-ireland-tour-of-netherlands-2021" target="_self" title="Netherlands v Ireland, 3rd ODI - Live">NED vs IRE - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/33806/eng-vs-nz-1st-test-new-zealand-tour-of-england-2021" target="_self" title="England v New Zealand, 1st Test - Match drawn">ENG vs NZ - Match drawn</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/36322/zima-vs-rsaa-1st-unofficial-test-south-africa-a-tour-of-zimbabwe-2021" target="_self" title="Zimbabwe A v South Africa A, 1st unofficial Test - Live">ZIMA vs RSAA - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/33292/ess-vs-notts-group-1-county-championship-2021" target="_self" title="Essex v Nottinghamshire, Group 1 - Match drawn">ESS vs NOTTS - Match drawn</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/33287/worcs-vs-dur-group-1-county-championship-2021" target="_self" title="Worcestershire v Durham, Group 1 - DUR Won">WORCS vs DUR - DUR Won</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">T20 LEAGUE</div><div class="cb-scg-srs-nm">T20 Blast 2021</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/33828/lancs-vs-derby-north-group-t20-blast-2021" target="_self" title="Lancashire v Derbyshire, North Group - Upcoming"><span class="cb-mm-mtch-tm">Lancashire vs Derbyshire</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">North Group</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">England v New Zealand, 2021</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/33806/eng-vs-nz-1st-test-england-v-new-zealand-2021" target="_self" title="England v New Zealand, 1st Test - Match drawn"><span class="cb-mm-mtch-tm">England vs New Zealand</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">1st Test</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-scg-srs-nm">Netherlands v Ireland,  ...
# });</script> <div class="cb-col cb-hm-mid cb-bg-white cb-hmpage" style="clear:both"> <div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>THE DIALOGUE ROOM</span></div><a href="/cricket-news/117661/the-uk-diaries-with-dinesh-karthik" title="The UK diaries, with Dinesh Karthik"><img alt="The UK diaries, with Dinesh Karthik" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c207510/the-uk-diaries-with-dinesh-ka.jpg" title="The UK diaries, with Dinesh Karthik" width="420"/><span class="cb-plus-ico cb-ico-premium" style="position: absolute;right: 5px;top: 42px; width: 35px;height: 50px;background-position: -527px -5px;"></span></a><h2 class="big-crd-hdln"><a href="/cricket-news/117661/the-uk-diaries-with-dinesh-karthik" title="The UK diaries, with Dinesh Karthik">	The UK diaries, with Dinesh Karthik</a></h2><div class="cb-nws-intr">In this edition of The Dialogue Room, Dinesh Karthik looks back at how trips to the UK have run parallel to many of his crests and troughs as an international cricketer</div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>NEW ZEALAND TOUR OF ENGLAND, 2021</span></div><a href="/cricket-news/117660/an-important-day-in-englands-development" title="An important day in England's development"><img alt="An important day in England's development" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c207509/an-important-day-in-englands.jpg" title="An important day in England's development" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/117660/an-important-day-in-englands-development" title="An important day in England's development">	An important day in England's development</a></h2><div class="cb-nws-intr">A draw against a quality New Zealand side is a creditable result to start the Test match summer, particularly when you consider the quality of the players England are missing</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/117664/dom-bess-added-to-squad-ahead-of-second-nz-test" title="Dom Bess added to squad ahead of second NZ Test">Dom Bess added to squad ahead of second NZ Test</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/117662/boult-could-play-second-test-after-relaxed-quarantine-protocols" title="Boult could play second Test after relaxed quarantine protocols">Boult could play second Test after relaxed quarantine protocols</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/117642/analysing-ollie-popes-technical-switch" title="Analysing Ollie Pope's technical switch">Analysing Ollie Pope's technical switch</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/117666/england-sanctioned-for-slow-over-rate-in-lords-test" title="England sanctioned for slow over rate in Lord's Test">England sanctioned for slow over rate in Lord's Test</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>NEW ZEALAND'S TOUR OF ENGLAND, 2021</span></div><a href="/cricket-news/117659/robinson-to-miss-edgbaston-test-after-ecb-hands-suspension" title="Robinson to miss Edgbaston Test after ECB hands suspension"><img alt="Robinson to miss Edgbaston Test after ECB hands suspension" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c207508/robinson-to-miss-edgbaston-tes.jpg" title="Robinson to miss Edgbaston Test after ECB hands suspension" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/117659/robinson-to-miss-edgbaston-test-after-ecb-hands-suspension" title="Robinson to miss Edgbaston Test after ECB hands suspension">	Robinson to miss Edgbaston Test after ECB hands suspension</a></h2><div class="cb-nws-intr">The fast bowler has been suspended from international cricket pending a board investigation into the racist and sexist tweets that resurfaced after his debut at the Lord's </div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# In this edition of The Dialogue Room, Dinesh Karthik looks back at how trips to the UK have run parallel to many of his crests and troughs as an international cricketer
#
#
# A draw against a quality New Zealand side is a creditable result to start the Test match summer, particularly when you consider the quality of the players England are missing
#
#
# The fast bowler has been suspended from international cricket pending a board investigation into the racist and sexist tweets that resurfaced after his debut at the Lord's
#
#
# England's manic schedule suggests that, even among cricket's wealthier members, no amount of cricket can sustain the game's existing structure as the cracks in the financial system increase in size
#
#
# Tim Southee has come a long way since his spiky-haired, baggy-shirted debut as a 19-year-old, but for all the accomplishments, nothing gives him greater joy than sharing the new ball with one of his best friends
#
#
# The Bangladesh wicketkeeper-bat will, however, remain available for the ODIs and Tests on the tour
#
#
# In a chat with Cricbuzz, the PCB chief executive opens up on what went behind the scenes to get Pakistan's premier T20 league up and running again
#
#
# With several key players featuring for their clubs and counties, Netherlands have been left severely hampered in their World Cricket League Championship against Scotland
#
#
# In a chat with TOI, the former New Zealand coach spoke on the WTC final, how the two teams are placed, and more
#
#
# As India enter another period in a bio-bubble, the India captain wants monitoring of mental health situation like they do with player workloads
#
#
# Somerset moved 10 points clear at the top of Group 2 standings following their draw against Hampshire
#
#
# Abhinav Mukund's personal account on the struggles of everyday life as a professional player in India
#
#
# The inside story of how the tournament fell apart midway through the season
#
#
# The coach of the world's second-ranked Test team is barely known outside of New Zealand, not that it bothers him. "The game is not about me," Gary Stead tells Cricbuzz in an engaging interview
#
#
# In the backdrop of yet another injury, we dive into the probable cause and effect of the conditioned bowling action
#
#
# In the third edition of Think Tank on Cricbuzz Plus, we look at why there is, now more than ever, a case for player engagement and psychological safety
#
#
# "Twenty years from now, cricket is going to be more league-based than international-based," tells du Plessis
#
#
# A basic query but there are no straightforward responses given the current era of batting we find ourselves in
#
#
# In an exclusive interview, the 19-year-old Rajasthan Royals batsman opens up on moulding his career as a middle-order batsman and his aspirations to progress as a finisher for the national team
#
#
# The 22-year-old wicketkeeper-batsman has managed to evolve over the last three years during his time with Mumbai Indians
#
#
# Destined to the fate of a cricketer, Devdutt owes a lot of his success to meticulous planning and forethought from his parents
#
#
# In 1981, Kapil Dev headed to Lancashire for a season of club cricket, where he would go head to head with a number of familiar faces from the international circuit, colleagues and opponents alike
#
#
# The 32-year-old is all set to become just the 11th pacer to feature in 100 Tests in the history of the game
